# %%
# !pip install SimpleITK
# !pip install sklearn

try:
  from google.colab import drive
  IN_COLAB = True
except:
  IN_COLAB = False

import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import SimpleITK as sitk
from sklearn.naive_bayes import GaussianNB
from sklearn import svm
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn import neighbors
from IPython.display import clear_output

clear_output()

# %%
drive.mount('colab/')

clear_output()

# %%
def read_kImage(path):
    # Reads the image using SimpleITK
    itkimage = sitk.ReadImage(path)
    # Convert the image to a  numpy array first and then shuffle the dimensions to get axis in the order z,y,x
    ct_scan = sitk.GetArrayFromImage(itkimage)
    return ct_scan

# %%
def extract_voxel_data(series_path):
    reader = sitk.ImageSeriesReader()
    dicom_names = reader.GetGDCMSeriesFileNames( series_path )
    reader.SetFileNames(dicom_names)
    image = reader.Execute()
    image_3d = sitk.GetArrayFromImage(image)
    return image_3d

# %%
def normalize_image(image_3D):
    z,y,x = image_3D.shape
    new_image_3D = np.empty(shape = (z,y,x) )
    target_min = -1
    target_max = 1
    for i in range (z):
        max_value = np.max (image_3D[i])
        min_value = np.min (image_3D[i])
        new_image_3D[i] = (image_3D[i] - min_value)*(float(target_max - target_min)/(max_value - min_value)) + target_min
    return new_image_3D

# %%
def subvoxel (img_3d,ijk, window):
    ijk = ijk.split()
    x = int(ijk[0])
    y = int(ijk[1])
    z = int(ijk[2])
    if (z < 0):
        z = z*(-1)
    new_img3d = np.empty(shape = (3,img_3d.shape[1], img_3d.shape[2]))
    max_bandwith = img_3d.shape[0] - 1
    if ( z == max_bandwith ):
        new_img3d[0,:,:] = img_3d[z-1,:,:] #n-1
        new_img3d[1,:,:] = img_3d[z,:,:] #n
        new_img3d[2,:,:] = img_3d[z,:,:] #n
    else:
        if (z == 0):
            new_img3d[0,:,:] = img_3d[z,:,:] #0
            new_img3d[1,:,:] = img_3d[z,:,:] #0
            new_img3d[2,:,:] = img_3d[z+1,:,:] #1
        else:
            new_img3d[0,:,:] = img_3d[z-1,:,:] #n-1
            new_img3d[1,:,:] = img_3d[z,:,:] #n
            new_img3d[2,:,:] = img_3d[z+1,:,:] #n+1
    window = window//2
    new_img3d = new_img3d[:, y-window : y+window, x-window : x+window]
    return new_img3d

# %%
def generate_training_dataframes():
    global IN_COLAB
    if (IN_COLAB):
      basedir= "/content/colab/My Drive/ProstateX_dataset/1/Train/ProstateX-TrainingLesionInformationv2/ProstateX-TrainingLesionInformationv2"
    else:
      basedir = "../1/train/ProstateX-TrainingLesionInformationv2/ProstateX-TrainingLesionInformationv2"
    findingsfile = "{}/{}".format(basedir,"ProstateX-Findings-Train.csv")
    imagesfile = "{}/{}".format(basedir,"ProstateX-Images-Train.csv")
    kimagesfile = "{}/{}".format(basedir,"ProstateX-Images-KTrans-Train.csv")
    #Generamos las 3 tablas básicas a partir de los archivos.cvs
    findings_table = pd.read_csv(findingsfile)
    images_table = pd.read_csv(imagesfile)
    kimages_table = pd.read_csv(kimagesfile)
    #Operación de inner join entre tablas.
    join_kimages_table = pd.merge(left=findings_table, right= kimages_table, how ="inner", on=["ProxID","fid"])
    join_images_table =  pd.merge(left=findings_table, right=  images_table, how ="inner", on=["ProxID","fid"])
    #agregamos una columna para insertar la imagen
    #agregamos una columna para los parches
    #agregamos otra columna para la integridad de los datos
    #agregamos otra columna para las predicciones
    join_images_table["MRI3D"] = pd.Series(np.zeros((len(join_images_table),2,2,2)).tolist(), index= join_images_table.index)
    join_images_table["MRIPatch3D"] = pd.Series(np.zeros((len(join_images_table),2,2,2)).tolist(), index= join_images_table.index)
    join_images_table["State"] = pd.Series(False, index= join_images_table.index)
    join_images_table["InterestSequence"] = pd.Series(False, index= join_images_table.index)
    join_images_table["Predictions"] = pd.Series(0, index= join_images_table.index)
    join_kimages_table["Kimg3D"] = pd.Series(np.zeros((len(join_kimages_table),2,2,2)).tolist(), index= join_kimages_table.index)
    join_kimages_table["KimgPatch3D"] = pd.Series(np.zeros((len(join_kimages_table),2,2,2)).tolist(), index= join_kimages_table.index)
    join_kimages_table["State"] = pd.Series(False, index= join_kimages_table.index)
    join_kimages_table["Predictions"] = pd.Series(0, index= join_kimages_table.index)
    return join_images_table, join_kimages_table

# %%
training_MRI_imgs_dataframe, training_ktrans_imgs_dataframe = generate_training_dataframes()

# %%
def isValid_data(img_3d, ijk):
    state = False
    k_string = ijk.split()[2]
    max_bandwith = img_3d.shape[0] -1
    possible_k = int (k_string)
    if (possible_k >= max_bandwith):
        possible_k = max_bandwith
        slice_index = possible_k
        state = True
        print("The ijk requested is [{}], there was an error since the shapes of the image is {}".format(ijk,str(img_3d.shape)))
    else:
        if possible_k >= 0:
            slice_index = possible_k
            print("The ijk requested is [{}],OK since shapes of the image is {}".format(ijk,str(img_3d.shape)))
        else:
            state = False
            print("The ijk requested is [{}],OK since shapes of the image is {}".format(ijk,str(img_3d.shape)))
    return state

# %%
def set_MRI_value(dataFrame,index,image3d,state,window):
    row = dataFrame.iloc[index]
    dataFrame.at[index,"MRI3D"] = image3d
    dataFrame.at[index,"State"] = state
    if state == False:
        dataFrame.at[index,"MRIPatch3D"] = subvoxel(img_3d=image3d, ijk=row.ijk, window=window)
    else:
        dataFrame.at[index,"MRIPatch3D"] = np.zeros(shape= (window,image3d.shape[0],image3d.shape[1]))

# %%
def set_kImg_value(dataFrame,index,image3d,state, window):
    row = dataFrame.iloc[index]
    dataFrame.at[index,"Kimg3D"] = image3d
    dataFrame.at[index,"State"] = state
    if state == False:
        dataFrame.at[index,"KimgPatch3D"] = subvoxel(img_3d=image3d, ijk=row.ijk, window=window)
    else:
        dataFrame.at[index,"KimgPatch3D"] = np.empty(shape= image3d.shape)

# %%
def fill_ktrans_images_dataframe_at_training(dataFrame, window):
    global IN_COLAB
    if window == None:
        window = 40
    for row in range(len(dataFrame)):
        
        if(IN_COLAB):
          path = "/content/colab/My Drive/ProstateX_dataset/1/Train/ProstateXKtrains-train-fixed"
        else:
          path = "../1/train/ProstateXKtrains-train-fixed"
        patient_id = dataFrame.ProxID.iloc[row]
        ijk = dataFrame.ijk.iloc[row]
        path = "{}/{}".format(path,patient_id)
        path = "{}/{}-Ktrans.mhd".format(path,patient_id)
        kimage_3d = read_kImage(path)
        kimage_3d = normalize_image(kimage_3d)
        state =  isValid_data(kimage_3d,ijk)
        set_kImg_value(dataFrame,row,kimage_3d,state,window)
        print("Se ha cargado la k-trans imagen3d #{} para el paciente {} ".format(row,patient_id))
        del path,patient_id,kimage_3d,state

# %%
window = 40
fill_ktrans_images_dataframe_at_training(dataFrame = training_ktrans_imgs_dataframe , window =window)
#fill_ktrans_images_dataframe_at_testing(dataFrame = testing_ktrans_imgs_dataframe, window = window)
clear_output()
print ("All the Ktrans training images were read correctly")
print ("All the Ktrans testing images were read correctly")
training_ktrans_imgs_dataframe = training_ktrans_imgs_dataframe[ training_ktrans_imgs_dataframe.State == False]
training_ktrans_imgs_dataframe.reset_index(drop=True)
training_ktrans_imgs_dataframe.index = pd.RangeIndex(len(training_ktrans_imgs_dataframe))
display(training_ktrans_imgs_dataframe[["ProxID", "fid", "ijk", "ClinSig"]].iloc[35:60])
# Out:
# All the Ktrans training images were read correctly
# All the Ktrans testing images were read correctly
#             ProxID  fid        ijk  ClinSig
# 35  ProstateX-0025    1   67 88 -7    False
# 36  ProstateX-0025    1    75 79 7    False
# 37  ProstateX-0025    1    81 77 7    False
# 38  ProstateX-0025    1   67 88 -7    False
# 39  ProstateX-0025    1    75 79 7    False
# 40  ProstateX-0025    1    81 77 7    False
# 41  ProstateX-0025    2   57 89 -7    False
# 42  ProstateX-0025    2    71 79 7    False
# 43  ProstateX-0025    3   46 80 -7    False
# 44  ProstateX-0025    3    60 70 8    False
# 45  ProstateX-0025    4  66 70 -12    False
# 46  ProstateX-0025    4    80 61 2    False
# 47  ProstateX-0026    1    59 66 5     True
# 48  ProstateX-0027    1    54 82 8    False
# 49  ProstateX-0028    1    79 70 6     True
# 50  ProstateX-0028    2    51 71 7    False
# 51  ProstateX-0029    1   72 78 10    False
# 52  ProstateX-0030    1   74 67 10    False
# 53  ProstateX-0031    1   77 69 11     True
# 54  ProstateX-0031    2   55 70 11    False
# 55  ProstateX-0032    1   77 81 14    False
# 56  ProstateX-0033    1    55 75 6    False
# 57  ProstateX-0033    3    71 69 5    False
# 58  ProstateX-0034    1   68 80 12    False
# 59  ProstateX-0035    1    50 66 7     True

# %%
def fill_MRI_images_dataframe_at_training(dataFrame, window):
    global IN_COLAB
    for row in range (len(dataFrame)):
        print("===============================================================")
        patient_id = dataFrame.ProxID.iloc[row]
        series_name = dataFrame.DCMSerDescr.iloc[row]
        series_id = dataFrame.DCMSerNum.iloc[row]
        slice_ijk = dataFrame.ijk.iloc[row]
        sequence_name = dataFrame.Name.iloc[row]
        if(IN_COLAB):
          path = "/content/colab/My Drive/ProstateX_dataset/1/Train/PROSTATEx/{}/".format(patient_id)#Selects the Patient ID
        else:
          path = "../1/train/PROSTATEx/{}/".format(patient_id)#Selects the Patient ID
        path = "{}/{}".format(path,os.listdir(path)[0])#Selects the default folder inside the patient
        sequences = os.listdir(path) # Selects all the sequences
        #sequence = [ sequence for sequence in sequences if sequence[0:len(str(series_id))] == str(series_id) ] [0]
        for sequence in sequences:
            sequence_id = sequence[0:len(str(series_id))]
            if (str(sequence_id) == str(series_id)):
                print ("The condition is true {} = {}".format(sequence_id,series_id))
                print ("The sequence selected is {}".format(sequence))
                print ("The requested sequence is {}".format(sequence_name))
                break
        # Selects the only sequence that matches the condition.
        path = "{}/{}".format(path,sequence)
        image_3d = extract_voxel_data(path)
        state = isValid_data(ijk=slice_ijk, img_3d=image_3d)
        set_MRI_value(dataFrame,row,image_3d,state,40)
        print("Se ha cargado la imagen MRI3D y MRI3DPATCH #{} para el paciente {} serie: {} ".format(row,patient_id,series_name))
        del path, patient_id, series_name, series_id,sequence,sequences, image_3d

# %%
fill_MRI_images_dataframe_at_training(dataFrame = training_MRI_imgs_dataframe, window = window)
clear_output()
print ("All the MRI training images were read correctly")
training_MRI_imgs_dataframe =training_MRI_imgs_dataframe[ training_MRI_imgs_dataframe.State == False]
training_MRI_imgs_dataframe.reset_index(drop=True)
training_MRI_imgs_dataframe.index = pd.RangeIndex(len(training_MRI_imgs_dataframe))
display(training_MRI_imgs_dataframe[["ProxID", "fid", "ijk", "ClinSig"]].iloc[35:60])
# Out:
# ===============================================================
# The condition is true 7 = 7
# The sequence selected is 7-ep2ddifftraDYNDISTADC-48780
# The requested sequence is ep2d_diff_tra_DYNDIST_ADC0
# The ijk requested is [36 72 9],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #0 para el paciente ProstateX-0000 serie: ep2d_diff_tra_DYNDIST_ADC
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-69284
# The requested sequence is ep2d_diff_tra_DYNDIST0
# The ijk requested is [36 72 9],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #1 para el paciente ProstateX-0000 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-69284
# The requested sequence is ep2d_diff_tra_DYNDIST1
# The ijk requested is [36 72 9],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #2 para el paciente ProstateX-0000 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-69284
# The requested sequence is ep2d_diff_tra_DYNDIST2
# The ijk requested is [36 72 9],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3 para el paciente ProstateX-0000 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 8 = 8
# The sequence selected is 8-ep2ddifftraDYNDISTCALCBVAL-83202
# The requested sequence is ep2d_diff_tra_DYNDISTCALC_BVAL0
# The ijk requested is [36 72 9],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #4 para el paciente ProstateX-0000 serie: ep2d_diff_tra_DYNDISTCALC_BVAL
# ===============================================================
# The condition is true 5 = 5
# The sequence selected is 5-t2tsecor-03471
# The requested sequence is t2_tse_cor0
# The ijk requested is [139 166 12],OK since shapes of the image is (15, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #5 para el paciente ProstateX-0000 serie: t2_tse_cor
# ===============================================================
# The condition is true 3 = 3
# The sequence selected is 3-t2tsesag-87368
# The requested sequence is t2_tse_sag0
# The ijk requested is [176 169 13],OK since shapes of the image is (19, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #6 para el paciente ProstateX-0000 serie: t2_tse_sag
# ===============================================================
# The condition is true 4 = 4
# The sequence selected is 4-t2tsetra-00702
# The requested sequence is t2_tse_tra0
# The ijk requested is [167 224 9],OK since shapes of the image is (19, 384, 384)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #7 para el paciente ProstateX-0000 serie: t2_tse_tra
# ===============================================================
# The condition is true 9 = 9
# The sequence selected is 9-tfl3d PD reftra1.5x1.5t3-67276
# The requested sequence is tfl_3d_PD_ref_tra_1_5x1_5_t30
# The ijk requested is [56 75 7],OK since shapes of the image is (16, 128, 128)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #8 para el paciente ProstateX-0000 serie: tfl_3d PD ref_tra_1.5x1.5_t3
# ===============================================================
# The condition is true 8 = 8
# The sequence selected is 8-ep2ddifftraDYNDISTMIXADC-33954
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX_ADC0
# The ijk requested is [34 63 10],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #9 para el paciente ProstateX-0001 serie: ep2d_diff_tra_DYNDIST_MIX_ADC
# ===============================================================
# The condition is true 7 = 7
# The sequence selected is 7-ep2ddifftraDYNDISTMIX-61648
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX0
# The ijk requested is [34 63 10],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #10 para el paciente ProstateX-0001 serie: ep2d_diff_tra_DYNDIST_MIX
# ===============================================================
# The condition is true 7 = 7
# The sequence selected is 7-ep2ddifftraDYNDISTMIX-61648
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX1
# The ijk requested is [34 63 10],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #11 para el paciente ProstateX-0001 serie: ep2d_diff_tra_DYNDIST_MIX
# ===============================================================
# The condition is true 7 = 7
# The sequence selected is 7-ep2ddifftraDYNDISTMIX-61648
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX2
# The ijk requested is [34 63 10],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #12 para el paciente ProstateX-0001 serie: ep2d_diff_tra_DYNDIST_MIX
# ===============================================================
# The condition is true 9 = 9
# The sequence selected is 9-ep2ddifftraDYNDISTMIXCALCBVAL-58431
# The requested sequence is ep2d_diff_tra_DYNDIST_MIXCALC_BVAL0
# The ijk requested is [34 63 10],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #13 para el paciente ProstateX-0001 serie: ep2d_diff_tra_DYNDIST_MIXCALC_BVAL
# ===============================================================
# The condition is true 3 = 3
# The sequence selected is 3-t2loc sag-52336
# The requested sequence is t2_loc_sag0
# The ijk requested is [126 145 3], there was an error since the shapes of the image is (3, 256, 256)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #14 para el paciente ProstateX-0001 serie: t2_loc sag
# ===============================================================
# The condition is true 1 = 1
# The sequence selected is 11-tfl3d PD reftra1.5x1.5t3-77124
# The requested sequence is t2_localizer0
# The ijk requested is [147 139 1],OK since shapes of the image is (16, 128, 128)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #15 para el paciente ProstateX-0001 serie: t2_localizer
# ===============================================================
# The condition is true 2 = 2
# The sequence selected is 2-t2localizer-46616
# The requested sequence is t2_localizer0
# The ijk requested is [147 139 1],OK since shapes of the image is (13, 256, 256)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #16 para el paciente ProstateX-0001 serie: t2_localizer
# ===============================================================
# The condition is true 5 = 5
# The sequence selected is 5-t2tsecor-26539
# The requested sequence is t2_tse_cor0
# The ijk requested is [131 177 6],OK since shapes of the image is (15, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #17 para el paciente ProstateX-0001 serie: t2_tse_cor
# ===============================================================
# The condition is true 4 = 4
# The sequence selected is 4-t2tsesag-22089
# The requested sequence is t2_tse_sag0
# The ijk requested is [154 173 15],OK since shapes of the image is (19, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #18 para el paciente ProstateX-0001 serie: t2_tse_sag
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-t2tsetra-76610
# The requested sequence is t2_tse_tra0
# The ijk requested is [157 186 10],OK since shapes of the image is (19, 384, 384)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #19 para el paciente ProstateX-0001 serie: t2_tse_tra
# ===============================================================
# The condition is true 10 = 10
# The sequence selected is 10-t2tsetra-17541
# The requested sequence is t2_tse_tra0
# The ijk requested is [157 186 10],OK since shapes of the image is (19, 384, 384)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #20 para el paciente ProstateX-0001 serie: t2_tse_tra
# ===============================================================
# The condition is true 11 = 11
# The sequence selected is 11-tfl3d PD reftra1.5x1.5t3-77124
# The requested sequence is tfl_3d_PD_ref_tra_1_5x1_5_t30
# The ijk requested is [51 61 6],OK since shapes of the image is (16, 128, 128)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #21 para el paciente ProstateX-0001 serie: tfl_3d PD ref_tra_1.5x1.5_t3
# ===============================================================
# The condition is true 7 = 7
# The sequence selected is 7-ep2ddifftraDYNDISTADC-78067
# The requested sequence is ep2d_diff_tra_DYNDIST_ADC0
# The ijk requested is [33 71 12],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #22 para el paciente ProstateX-0002 serie: ep2d_diff_tra_DYNDIST_ADC
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-79751
# The requested sequence is ep2d_diff_tra_DYNDIST0
# The ijk requested is [33 71 12],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #23 para el paciente ProstateX-0002 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-79751
# The requested sequence is ep2d_diff_tra_DYNDIST1
# The ijk requested is [33 71 12],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #24 para el paciente ProstateX-0002 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-79751
# The requested sequence is ep2d_diff_tra_DYNDIST2
# The ijk requested is [33 71 12],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #25 para el paciente ProstateX-0002 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 8 = 8
# The sequence selected is 8-ep2ddifftraDYNDISTCALCBVAL-65650
# The requested sequence is ep2d_diff_tra_DYNDISTCALC_BVAL0
# The ijk requested is [33 71 12],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #26 para el paciente ProstateX-0002 serie: ep2d_diff_tra_DYNDISTCALC_BVAL
# ===============================================================
# The condition is true 2 = 2
# The sequence selected is 2-t2loc sag-80387
# The requested sequence is t2_loc_sag0
# The ijk requested is [135 132 3], there was an error since the shapes of the image is (3, 256, 256)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #27 para el paciente ProstateX-0002 serie: t2_loc sag
# ===============================================================
# The condition is true 1 = 1
# The sequence selected is 1-t2localizer-64390
# The requested sequence is t2_localizer0
# The ijk requested is [155 145 1],OK since shapes of the image is (13, 256, 256)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #28 para el paciente ProstateX-0002 serie: t2_localizer
# ===============================================================
# The condition is true 5 = 5
# The sequence selected is 5-t2tsecor-52380
# The requested sequence is t2_tse_cor0
# The ijk requested is [128 171 12],OK since shapes of the image is (15, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #29 para el paciente ProstateX-0002 serie: t2_tse_cor
# ===============================================================
# The condition is true 3 = 3
# The sequence selected is 3-t2tsesag-02864
# The requested sequence is t2_tse_sag0
# The ijk requested is [183 154 15],OK since shapes of the image is (19, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #30 para el paciente ProstateX-0002 serie: t2_tse_sag
# ===============================================================
# The condition is true 4 = 4
# The sequence selected is 4-t2tsetra-44920
# The requested sequence is t2_tse_tra0
# The ijk requested is [154 217 12],OK since shapes of the image is (19, 384, 384)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #31 para el paciente ProstateX-0002 serie: t2_tse_tra
# ===============================================================
# The condition is true 9 = 9
# The sequence selected is 9-tfl3d PD reftra1.5x1.5t3-99219
# The requested sequence is tfl_3d_PD_ref_tra_1_5x1_5_t30
# The ijk requested is [52 73 11],OK since shapes of the image is (16, 128, 128)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #32 para el paciente ProstateX-0002 serie: tfl_3d PD ref_tra_1.5x1.5_t3
# ===============================================================
# The condition is true 7 = 7
# The sequence selected is 7-ep2ddifftraDYNDISTADC-78067
# The requested sequence is ep2d_diff_tra_DYNDIST_ADC0
# The ijk requested is [45 70 9],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #33 para el paciente ProstateX-0002 serie: ep2d_diff_tra_DYNDIST_ADC
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-79751
# The requested sequence is ep2d_diff_tra_DYNDIST0
# The ijk requested is [45 70 9],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #34 para el paciente ProstateX-0002 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-79751
# The requested sequence is ep2d_diff_tra_DYNDIST1
# The ijk requested is [45 70 9],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #35 para el paciente ProstateX-0002 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-79751
# The requested sequence is ep2d_diff_tra_DYNDIST2
# The ijk requested is [45 70 9],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #36 para el paciente ProstateX-0002 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 8 = 8
# The sequence selected is 8-ep2ddifftraDYNDISTCALCBVAL-65650
# The requested sequence is ep2d_diff_tra_DYNDISTCALC_BVAL0
# The ijk requested is [45 70 9],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #37 para el paciente ProstateX-0002 serie: ep2d_diff_tra_DYNDISTCALC_BVAL
# ===============================================================
# The condition is true 2 = 2
# The sequence selected is 2-t2loc sag-80387
# The requested sequence is t2_loc_sag0
# The ijk requested is [134 137 1],OK since shapes of the image is (3, 256, 256)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #38 para el paciente ProstateX-0002 serie: t2_loc sag
# ===============================================================
# The condition is true 1 = 1
# The sequence selected is 1-t2localizer-64390
# The requested sequence is t2_localizer0
# The ijk requested is [153 151 0],OK since shapes of the image is (13, 256, 256)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #39 para el paciente ProstateX-0002 serie: t2_localizer
# ===============================================================
# The condition is true 5 = 5
# The sequence selected is 5-t2tsecor-52380
# The requested sequence is t2_tse_cor0
# The ijk requested is [170 186 12],OK since shapes of the image is (15, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #40 para el paciente ProstateX-0002 serie: t2_tse_cor
# ===============================================================
# The condition is true 3 = 3
# The sequence selected is 3-t2tsesag-02864
# The requested sequence is t2_tse_sag0
# The ijk requested is [178 169 8],OK since shapes of the image is (19, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #41 para el paciente ProstateX-0002 serie: t2_tse_sag
# ===============================================================
# The condition is true 4 = 4
# The sequence selected is 4-t2tsetra-44920
# The requested sequence is t2_tse_tra0
# The ijk requested is [203 216 10],OK since shapes of the image is (19, 384, 384)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #42 para el paciente ProstateX-0002 serie: t2_tse_tra
# ===============================================================
# The condition is true 9 = 9
# The sequence selected is 9-tfl3d PD reftra1.5x1.5t3-99219
# The requested sequence is tfl_3d_PD_ref_tra_1_5x1_5_t30
# The ijk requested is [68 72 8],OK since shapes of the image is (16, 128, 128)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #43 para el paciente ProstateX-0002 serie: tfl_3d PD ref_tra_1.5x1.5_t3
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDISTADC-83547
# The requested sequence is ep2d_diff_tra_DYNDIST_ADC0
# The ijk requested is [54 68 11],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #44 para el paciente ProstateX-0003 serie: ep2d_diff_tra_DYNDIST_ADC
# ===============================================================
# The condition is true 5 = 5
# The sequence selected is 5-ep2ddifftraDYNDIST-12594
# The requested sequence is ep2d_diff_tra_DYNDIST0
# The ijk requested is [54 68 11],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #45 para el paciente ProstateX-0003 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 5 = 5
# The sequence selected is 5-ep2ddifftraDYNDIST-12594
# The requested sequence is ep2d_diff_tra_DYNDIST1
# The ijk requested is [54 68 11],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #46 para el paciente ProstateX-0003 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 5 = 5
# The sequence selected is 5-ep2ddifftraDYNDIST-12594
# The requested sequence is ep2d_diff_tra_DYNDIST2
# The ijk requested is [54 68 11],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #47 para el paciente ProstateX-0003 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 7 = 7
# The sequence selected is 7-ep2ddifftraDYNDISTCALCBVAL-86046
# The requested sequence is ep2d_diff_tra_DYNDISTCALC_BVAL0
# The ijk requested is [54 68 11],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #48 para el paciente ProstateX-0003 serie: ep2d_diff_tra_DYNDISTCALC_BVAL
# ===============================================================
# The condition is true 1 = 1
# The sequence selected is 1-t2localizer-71616
# The requested sequence is t2_localizer0
# The ijk requested is [149 130 0],OK since shapes of the image is (13, 256, 256)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #49 para el paciente ProstateX-0003 serie: t2_localizer
# ===============================================================
# The condition is true 4 = 4
# The sequence selected is 4-t2tsecor-19765
# The requested sequence is t2_tse_cor0
# The ijk requested is [199 154 14],OK since shapes of the image is (17, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #50 para el paciente ProstateX-0003 serie: t2_tse_cor
# ===============================================================
# The condition is true 2 = 2
# The sequence selected is 2-t2tsesag-41933
# The requested sequence is t2_tse_sag0
# The ijk requested is [168 165 3],OK since shapes of the image is (19, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #51 para el paciente ProstateX-0003 serie: t2_tse_sag
# ===============================================================
# The condition is true 3 = 3
# The sequence selected is 3-t2tsetra-30967
# The requested sequence is t2_tse_tra0
# The ijk requested is [240 205 12],OK since shapes of the image is (21, 384, 384)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #52 para el paciente ProstateX-0003 serie: t2_tse_tra
# ===============================================================
# The condition is true 8 = 8
# The sequence selected is 8-tfl3d PD reftra1.5x1.5t3-34713
# The requested sequence is tfl_3d_PD_ref_tra_1_5x1_5_t30
# The ijk requested is [80 69 10],OK since shapes of the image is (16, 128, 128)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #53 para el paciente ProstateX-0003 serie: tfl_3d PD ref_tra_1.5x1.5_t3
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDISTADC-83547
# The requested sequence is ep2d_diff_tra_DYNDIST_ADC0
# The ijk requested is [33 57 16],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #54 para el paciente ProstateX-0003 serie: ep2d_diff_tra_DYNDIST_ADC
# ===============================================================
# The condition is true 5 = 5
# The sequence selected is 5-ep2ddifftraDYNDIST-12594
# The requested sequence is ep2d_diff_tra_DYNDIST0
# The ijk requested is [33 57 16],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #55 para el paciente ProstateX-0003 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 5 = 5
# The sequence selected is 5-ep2ddifftraDYNDIST-12594
# The requested sequence is ep2d_diff_tra_DYNDIST1
# The ijk requested is [33 57 16],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #56 para el paciente ProstateX-0003 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 5 = 5
# The sequence selected is 5-ep2ddifftraDYNDIST-12594
# The requested sequence is ep2d_diff_tra_DYNDIST2
# The ijk requested is [33 57 16],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #57 para el paciente ProstateX-0003 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 7 = 7
# The sequence selected is 7-ep2ddifftraDYNDISTCALCBVAL-86046
# The requested sequence is ep2d_diff_tra_DYNDISTCALC_BVAL0
# The ijk requested is [33 57 16],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #58 para el paciente ProstateX-0003 serie: ep2d_diff_tra_DYNDISTCALC_BVAL
# ===============================================================
# The condition is true 1 = 1
# The sequence selected is 1-t2localizer-71616
# The requested sequence is t2_localizer0
# The ijk requested is [141 116 1],OK since shapes of the image is (13, 256, 256)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #59 para el paciente ProstateX-0003 serie: t2_localizer
# ===============================================================
# The condition is true 4 = 4
# The sequence selected is 4-t2tsecor-19765
# The requested sequence is t2_tse_cor0
# The ijk requested is [126 134 7],OK since shapes of the image is (17, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #60 para el paciente ProstateX-0003 serie: t2_tse_cor
# ===============================================================
# The condition is true 2 = 2
# The sequence selected is 2-t2tsesag-41933
# The requested sequence is t2_tse_sag0
# The ijk requested is [147 125 15],OK since shapes of the image is (19, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #61 para el paciente ProstateX-0003 serie: t2_tse_sag
# ===============================================================
# The condition is true 3 = 3
# The sequence selected is 3-t2tsetra-30967
# The requested sequence is t2_tse_tra0
# The ijk requested is [153 161 17],OK since shapes of the image is (21, 384, 384)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #62 para el paciente ProstateX-0003 serie: t2_tse_tra
# ===============================================================
# The condition is true 8 = 8
# The sequence selected is 8-tfl3d PD reftra1.5x1.5t3-34713
# The requested sequence is tfl_3d_PD_ref_tra_1_5x1_5_t30
# The ijk requested is [51 54 13],OK since shapes of the image is (16, 128, 128)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #63 para el paciente ProstateX-0003 serie: tfl_3d PD ref_tra_1.5x1.5_t3
# ===============================================================
# The condition is true 7 = 7
# The sequence selected is 7-ep2ddifftraDYNDISTMIXADC-91158
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX_ADC0
# The ijk requested is [50 58 8],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #64 para el paciente ProstateX-0004 serie: ep2d_diff_tra_DYNDIST_MIX_ADC
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDISTMIX-13414
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX0
# The ijk requested is [50 58 8],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #65 para el paciente ProstateX-0004 serie: ep2d_diff_tra_DYNDIST_MIX
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDISTMIX-13414
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX1
# The ijk requested is [50 58 8],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #66 para el paciente ProstateX-0004 serie: ep2d_diff_tra_DYNDIST_MIX
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDISTMIX-13414
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX2
# The ijk requested is [50 58 8],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #67 para el paciente ProstateX-0004 serie: ep2d_diff_tra_DYNDIST_MIX
# ===============================================================
# The condition is true 8 = 8
# The sequence selected is 8-ep2ddifftraDYNDISTMIXCALCBVAL-20138
# The requested sequence is ep2d_diff_tra_DYNDIST_MIXCALC_BVAL0
# The ijk requested is [50 58 8],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #68 para el paciente ProstateX-0004 serie: ep2d_diff_tra_DYNDIST_MIXCALC_BVAL
# ===============================================================
# The condition is true 4 = 4
# The sequence selected is 4-t2tsecor-63070
# The requested sequence is t2_tse_cor0
# The ijk requested is [173 172 7],OK since shapes of the image is (21, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #69 para el paciente ProstateX-0004 serie: t2_tse_cor
# ===============================================================
# The condition is true 3 = 3
# The sequence selected is 3-t2tsesag-00386
# The requested sequence is t2_tse_sag0
# The ijk requested is [132 174 7],OK since shapes of the image is (19, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #70 para el paciente ProstateX-0004 serie: t2_tse_sag
# ===============================================================
# The condition is true 5 = 5
# The sequence selected is 5-t2tsetra-75680
# The requested sequence is t2_tse_tra0
# The ijk requested is [221 168 7],OK since shapes of the image is (19, 384, 384)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #71 para el paciente ProstateX-0004 serie: t2_tse_tra
# ===============================================================
# The condition is true 9 = 9
# The sequence selected is 9-tfl3d PD reftra1.5x1.5t3-38903
# The requested sequence is tfl_3d_PD_ref_tra_1_5x1_5_t30
# The ijk requested is [74 56 6],OK since shapes of the image is (16, 128, 128)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #72 para el paciente ProstateX-0004 serie: tfl_3d PD ref_tra_1.5x1.5_t3
# ===============================================================
# The condition is true 7 = 7
# The sequence selected is 7-ep2ddifftraDYNDISTMIXADC-16270
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX_ADC0
# The ijk requested is [46 75 9],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #73 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIX_ADC
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDISTMIX-30883
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX0
# The ijk requested is [46 75 9],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #74 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIX
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDISTMIX-30883
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX1
# The ijk requested is [46 75 9],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #75 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIX
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDISTMIX-30883
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX2
# The ijk requested is [46 75 9],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #76 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIX
# ===============================================================
# The condition is true 8 = 8
# The sequence selected is 8-ep2ddifftraDYNDISTMIXCALCBVAL-18975
# The requested sequence is ep2d_diff_tra_DYNDIST_MIXCALC_BVAL0
# The ijk requested is [46 75 9],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #77 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIXCALC_BVAL
# ===============================================================
# The condition is true 5 = 5
# The sequence selected is 5-t2tsecor-05098
# The requested sequence is t2_tse_cor0
# The ijk requested is [168 151 12],OK since shapes of the image is (15, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #78 para el paciente ProstateX-0005 serie: t2_tse_cor
# ===============================================================
# The condition is true 3 = 3
# The sequence selected is 3-t2tsesag-65685
# The requested sequence is t2_tse_sag0
# The ijk requested is [197 154 8],OK since shapes of the image is (19, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #79 para el paciente ProstateX-0005 serie: t2_tse_sag
# ===============================================================
# The condition is true 4 = 4
# The sequence selected is 4-t2tsetra-91330
# The requested sequence is t2_tse_tra0
# The ijk requested is [206 233 10],OK since shapes of the image is (19, 384, 384)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #80 para el paciente ProstateX-0005 serie: t2_tse_tra
# ===============================================================
# The condition is true 9 = 9
# The sequence selected is 9-tfl3d PD reftra1.5x1.5t3-17991
# The requested sequence is tfl_3d_PD_ref_tra_1_5x1_5_t30
# The ijk requested is [69 78 8],OK since shapes of the image is (16, 128, 128)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #81 para el paciente ProstateX-0005 serie: tfl_3d PD ref_tra_1.5x1.5_t3
# ===============================================================
# The condition is true 7 = 7
# The sequence selected is 7-ep2ddifftraDYNDISTMIXADC-16270
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX_ADC0
# The ijk requested is [42 63 9],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #82 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIX_ADC
# ===============================================================
# The condition is true 7 = 7
# The sequence selected is 7-ep2ddifftraDYNDISTMIXADC-16270
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX_ADC0
# The ijk requested is [34 71 9],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #83 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIX_ADC
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDISTMIX-30883
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX0
# The ijk requested is [42 63 9],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #84 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIX
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDISTMIX-30883
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX0
# The ijk requested is [34 71 9],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #85 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIX
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDISTMIX-30883
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX1
# The ijk requested is [42 63 9],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #86 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIX
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDISTMIX-30883
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX1
# The ijk requested is [34 71 9],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #87 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIX
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDISTMIX-30883
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX2
# The ijk requested is [42 63 9],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #88 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIX
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDISTMIX-30883
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX2
# The ijk requested is [34 71 9],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #89 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIX
# ===============================================================
# The condition is true 8 = 8
# The sequence selected is 8-ep2ddifftraDYNDISTMIXCALCBVAL-18975
# The requested sequence is ep2d_diff_tra_DYNDIST_MIXCALC_BVAL0
# The ijk requested is [42 63 9],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #90 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIXCALC_BVAL
# ===============================================================
# The condition is true 8 = 8
# The sequence selected is 8-ep2ddifftraDYNDISTMIXCALCBVAL-18975
# The requested sequence is ep2d_diff_tra_DYNDIST_MIXCALC_BVAL0
# The ijk requested is [34 71 9],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #91 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIXCALC_BVAL
# ===============================================================
# The condition is true 5 = 5
# The sequence selected is 5-t2tsecor-05098
# The requested sequence is t2_tse_cor0
# The ijk requested is [156 151 4],OK since shapes of the image is (15, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #92 para el paciente ProstateX-0005 serie: t2_tse_cor
# ===============================================================
# The condition is true 5 = 5
# The sequence selected is 5-t2tsecor-05098
# The requested sequence is t2_tse_cor0
# The ijk requested is [128 151 10],OK since shapes of the image is (15, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #93 para el paciente ProstateX-0005 serie: t2_tse_cor
# ===============================================================
# The condition is true 3 = 3
# The sequence selected is 3-t2tsesag-65685
# The requested sequence is t2_tse_sag0
# The ijk requested is [154 151 10],OK since shapes of the image is (19, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #94 para el paciente ProstateX-0005 serie: t2_tse_sag
# ===============================================================
# The condition is true 3 = 3
# The sequence selected is 3-t2tsesag-65685
# The requested sequence is t2_tse_sag0
# The ijk requested is [184 153 15],OK since shapes of the image is (19, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #95 para el paciente ProstateX-0005 serie: t2_tse_sag
# ===============================================================
# The condition is true 4 = 4
# The sequence selected is 4-t2tsetra-91330
# The requested sequence is t2_tse_tra0
# The ijk requested is [190 185 10],OK since shapes of the image is (19, 384, 384)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #96 para el paciente ProstateX-0005 serie: t2_tse_tra
# ===============================================================
# The condition is true 4 = 4
# The sequence selected is 4-t2tsetra-91330
# The requested sequence is t2_tse_tra0
# The ijk requested is [157 219 10],OK since shapes of the image is (19, 384, 384)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #97 para el paciente ProstateX-0005 serie: t2_tse_tra
# ===============================================================
# The condition is true 9 = 9
# The sequence selected is 9-tfl3d PD reftra1.5x1.5t3-17991
# The requested sequence is tfl_3d_PD_ref_tra_1_5x1_5_t30
# The ijk requested is [64 62 8],OK since shapes of the image is (16, 128, 128)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #98 para el paciente ProstateX-0005 serie: tfl_3d PD ref_tra_1.5x1.5_t3
# ===============================================================
# The condition is true 9 = 9
# The sequence selected is 9-tfl3d PD reftra1.5x1.5t3-17991
# The requested sequence is tfl_3d_PD_ref_tra_1_5x1_5_t30
# The ijk requested is [53 73 8],OK since shapes of the image is (16, 128, 128)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #99 para el paciente ProstateX-0005 serie: tfl_3d PD ref_tra_1.5x1.5_t3
# ===============================================================
# The condition is true 7 = 7
# The sequence selected is 7-ep2ddifftraDYNDISTMIXADC-16270
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX_ADC0
# The ijk requested is [42 63 9],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #100 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIX_ADC
# ===============================================================
# The condition is true 7 = 7
# The sequence selected is 7-ep2ddifftraDYNDISTMIXADC-16270
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX_ADC0
# The ijk requested is [34 71 9],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #101 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIX_ADC
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDISTMIX-30883
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX0
# The ijk requested is [42 63 9],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #102 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIX
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDISTMIX-30883
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX0
# The ijk requested is [34 71 9],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #103 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIX
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDISTMIX-30883
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX1
# The ijk requested is [42 63 9],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #104 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIX
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDISTMIX-30883
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX1
# The ijk requested is [34 71 9],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #105 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIX
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDISTMIX-30883
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX2
# The ijk requested is [42 63 9],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #106 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIX
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDISTMIX-30883
# The requested sequence is ep2d_diff_tra_DYNDIST_MIX2
# The ijk requested is [34 71 9],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #107 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIX
# ===============================================================
# The condition is true 8 = 8
# The sequence selected is 8-ep2ddifftraDYNDISTMIXCALCBVAL-18975
# The requested sequence is ep2d_diff_tra_DYNDIST_MIXCALC_BVAL0
# The ijk requested is [42 63 9],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #108 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIXCALC_BVAL
# ===============================================================
# The condition is true 8 = 8
# The sequence selected is 8-ep2ddifftraDYNDISTMIXCALCBVAL-18975
# The requested sequence is ep2d_diff_tra_DYNDIST_MIXCALC_BVAL0
# The ijk requested is [34 71 9],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #109 para el paciente ProstateX-0005 serie: ep2d_diff_tra_DYNDIST_MIXCALC_BVAL
# ===============================================================
# The condition is true 5 = 5
# The sequence selected is 5-t2tsecor-05098
# The requested sequence is t2_tse_cor0
# The ijk requested is [156 151 4],OK since shapes of the image is (15, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #110 para el paciente ProstateX-0005 serie: t2_tse_cor
# ===============================================================
# The condition is true 5 = 5
# The sequence selected is 5-t2tsecor-05098
# The requested sequence is t2_tse_cor0
# The ijk requested is [128 151 10],OK since shapes of the image is (15, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #111 para el paciente ProstateX-0005 serie: t2_tse_cor
# ===============================================================
# The condition is true 3 = 3
# The sequence selected is 3-t2tsesag-65685
# The requested sequence is t2_tse_sag0
# The ijk requested is [154 151 10],OK since shapes of the image is (19, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #112 para el paciente ProstateX-0005 serie: t2_tse_sag
# ===============================================================
# The condition is true 3 = 3
# The sequence selected is 3-t2tsesag-65685
# The requested sequence is t2_tse_sag0
# The ijk requested is [184 153 15],OK since shapes of the image is (19, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #113 para el paciente ProstateX-0005 serie: t2_tse_sag
# ===============================================================
# The condition is true 4 = 4
# The sequence selected is 4-t2tsetra-91330
# The requested sequence is t2_tse_tra0
# The ijk requested is [190 185 10],OK since shapes of the image is (19, 384, 384)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #114 para el paciente ProstateX-0005 serie: t2_tse_tra
# ===============================================================
# The condition is true 4 = 4
# The sequence selected is 4-t2tsetra-91330
# The requested sequence is t2_tse_tra0
# The ijk requested is [157 219 10],OK since shapes of the image is (19, 384, 384)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #115 para el paciente ProstateX-0005 serie: t2_tse_tra
# ===============================================================
# The condition is true 9 = 9
# The sequence selected is 9-tfl3d PD reftra1.5x1.5t3-17991
# The requested sequence is tfl_3d_PD_ref_tra_1_5x1_5_t30
# The ijk requested is [64 62 8],OK since shapes of the image is (16, 128, 128)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #116 para el paciente ProstateX-0005 serie: tfl_3d PD ref_tra_1.5x1.5_t3
# ===============================================================
# The condition is true 9 = 9
# The sequence selected is 9-tfl3d PD reftra1.5x1.5t3-17991
# The requested sequence is tfl_3d_PD_ref_tra_1_5x1_5_t30
# The ijk requested is [53 73 8],OK since shapes of the image is (16, 128, 128)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #117 para el paciente ProstateX-0005 serie: tfl_3d PD ref_tra_1.5x1.5_t3
# ===============================================================
# The condition is true 7 = 7
# The sequence selected is 7-ep2ddifftraDYNDISTADC-34068
# The requested sequence is ep2d_diff_tra_DYNDIST_ADC0
# The ijk requested is [50 69 11],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #118 para el paciente ProstateX-0006 serie: ep2d_diff_tra_DYNDIST_ADC
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-60838
# The requested sequence is ep2d_diff_tra_DYNDIST0
# The ijk requested is [50 69 11],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #119 para el paciente ProstateX-0006 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-60838
# The requested sequence is ep2d_diff_tra_DYNDIST1
# The ijk requested is [50 69 11],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #120 para el paciente ProstateX-0006 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-60838
# The requested sequence is ep2d_diff_tra_DYNDIST2
# The ijk requested is [50 69 11],OK since shapes of the image is (57, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #121 para el paciente ProstateX-0006 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 8 = 8
# The sequence selected is 8-ep2ddifftraDYNDISTCALCBVAL-06598
# The requested sequence is ep2d_diff_tra_DYNDISTCALC_BVAL0
# The ijk requested is [50 69 11],OK since shapes of the image is (19, 128, 84)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #122 para el paciente ProstateX-0006 serie: ep2d_diff_tra_DYNDISTCALC_BVAL
# ===============================================================
# The condition is true 2 = 2
# The sequence selected is 2-t2loc sag-12049
# The requested sequence is t2_loc_sag0
# The ijk requested is [144 146 0],OK since shapes of the image is (3, 256, 256)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #123 para el paciente ProstateX-0006 serie: t2_loc sag
# ===============================================================
# The condition is true 1 = 1
# The sequence selected is 1-t2localizer-77873
# The requested sequence is t2_localizer0
# The ijk requested is [147 135 0],OK since shapes of the image is (13, 256, 256)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #124 para el paciente ProstateX-0006 serie: t2_localizer
# ===============================================================
# The condition is true 5 = 5
# The sequence selected is 5-t2tsecor-47733
# The requested sequence is t2_tse_cor0
# The ijk requested is [182 159 11],OK since shapes of the image is (15, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #125 para el paciente ProstateX-0006 serie: t2_tse_cor
# ===============================================================
# The condition is true 3 = 3
# The sequence selected is 3-t2tsesag-19869
# The requested sequence is t2_tse_sag0
# The ijk requested is [163 160 6],OK since shapes of the image is (19, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #126 para el paciente ProstateX-0006 serie: t2_tse_sag
# ...
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-55863
# The requested sequence is ep2d_diff_tra_DYNDIST2
# The ijk requested is [54 71 12],OK since shapes of the image is (57, 128, 120)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3418 para el paciente ProstateX-0192 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 8 = 8
# The sequence selected is 8-ep2ddifftraDYNDISTCALCBVAL-54159
# The requested sequence is ep2d_diff_tra_DYNDISTCALC_BVAL0
# The ijk requested is [54 71 12],OK since shapes of the image is (19, 128, 120)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3419 para el paciente ProstateX-0192 serie: ep2d_diff_tra_DYNDISTCALC_BVAL
# ===============================================================
# The condition is true 5 = 5
# The sequence selected is 5-t2tsecor-41913
# The requested sequence is t2_tse_cor0
# The ijk requested is [135 155 12],OK since shapes of the image is (15, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3420 para el paciente ProstateX-0192 serie: t2_tse_cor
# ===============================================================
# The condition is true 3 = 3
# The sequence selected is 3-t2tsesag-00541
# The requested sequence is t2_tse_sag0
# The ijk requested is [178 177 14],OK since shapes of the image is (19, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3421 para el paciente ProstateX-0192 serie: t2_tse_sag
# ===============================================================
# The condition is true 4 = 4
# The sequence selected is 4-t2tsetra-62626
# The requested sequence is t2_tse_tra0
# The ijk requested is [168 218 11],OK since shapes of the image is (19, 384, 384)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3422 para el paciente ProstateX-0192 serie: t2_tse_tra
# ===============================================================
# The condition is true 9 = 9
# The sequence selected is 9-tfl3d PD reftra1.5x1.5t3-40574
# The requested sequence is tfl_3d_PD_ref_tra_1_5x1_5_t30
# The ijk requested is [56 73 10],OK since shapes of the image is (16, 128, 128)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3423 para el paciente ProstateX-0192 serie: tfl_3d PD ref_tra_1.5x1.5_t3
# ===============================================================
# The condition is true 7 = 7
# The sequence selected is 7-ep2ddifftraDYNDISTADC-04182
# The requested sequence is ep2d_diff_tra_DYNDIST_ADC0
# The ijk requested is [58 53 8],OK since shapes of the image is (19, 128, 120)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3424 para el paciente ProstateX-0193 serie: ep2d_diff_tra_DYNDIST_ADC
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-26905
# The requested sequence is ep2d_diff_tra_DYNDIST0
# The ijk requested is [58 53 8],OK since shapes of the image is (57, 128, 120)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3425 para el paciente ProstateX-0193 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-26905
# The requested sequence is ep2d_diff_tra_DYNDIST1
# The ijk requested is [58 53 8],OK since shapes of the image is (57, 128, 120)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3426 para el paciente ProstateX-0193 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-26905
# The requested sequence is ep2d_diff_tra_DYNDIST2
# The ijk requested is [58 53 8],OK since shapes of the image is (57, 128, 120)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3427 para el paciente ProstateX-0193 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 8 = 8
# The sequence selected is 8-ep2ddifftraDYNDISTCALCBVAL-27743
# The requested sequence is ep2d_diff_tra_DYNDISTCALC_BVAL0
# The ijk requested is [58 53 8],OK since shapes of the image is (19, 128, 120)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3428 para el paciente ProstateX-0193 serie: ep2d_diff_tra_DYNDISTCALC_BVAL
# ===============================================================
# The condition is true 2 = 2
# The sequence selected is 2-t2loc sag-46184
# The requested sequence is t2_loc_sag0
# The ijk requested is [116 130 2], there was an error since the shapes of the image is (3, 256, 256)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3429 para el paciente ProstateX-0193 serie: t2_loc sag
# ===============================================================
# The condition is true 1 = 1
# The sequence selected is 1-t2localizer-68630
# The requested sequence is t2_localizer0
# The ijk requested is [136 122 0],OK since shapes of the image is (13, 256, 256)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3430 para el paciente ProstateX-0193 serie: t2_localizer
# ===============================================================
# The condition is true 5 = 5
# The sequence selected is 5-t2tsecor-45586
# The requested sequence is t2_tse_cor0
# The ijk requested is [165 153 1],OK since shapes of the image is (15, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3431 para el paciente ProstateX-0193 serie: t2_tse_cor
# ===============================================================
# The condition is true 3 = 3
# The sequence selected is 3-t2tsesag-46320
# The requested sequence is t2_tse_sag0
# The ijk requested is [127 147 10],OK since shapes of the image is (19, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3432 para el paciente ProstateX-0193 serie: t2_tse_sag
# ===============================================================
# The condition is true 4 = 4
# The sequence selected is 4-t2tsetra-90291
# The requested sequence is t2_tse_tra0
# The ijk requested is [184 145 8],OK since shapes of the image is (19, 384, 384)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3433 para el paciente ProstateX-0193 serie: t2_tse_tra
# ===============================================================
# The condition is true 9 = 9
# The sequence selected is 9-tfl3d PD reftra1.5x1.5t3-19551
# The requested sequence is tfl_3d_PD_ref_tra_1_5x1_5_t30
# The ijk requested is [62 49 7],OK since shapes of the image is (16, 128, 128)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3434 para el paciente ProstateX-0193 serie: tfl_3d PD ref_tra_1.5x1.5_t3
# ===============================================================
# The condition is true 7 = 7
# The sequence selected is 7-ep2ddifftraDYNDISTADC-04182
# The requested sequence is ep2d_diff_tra_DYNDIST_ADC0
# The ijk requested is [65 69 11],OK since shapes of the image is (19, 128, 120)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3435 para el paciente ProstateX-0193 serie: ep2d_diff_tra_DYNDIST_ADC
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-26905
# The requested sequence is ep2d_diff_tra_DYNDIST0
# The ijk requested is [65 69 11],OK since shapes of the image is (57, 128, 120)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3436 para el paciente ProstateX-0193 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-26905
# The requested sequence is ep2d_diff_tra_DYNDIST1
# The ijk requested is [65 69 11],OK since shapes of the image is (57, 128, 120)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3437 para el paciente ProstateX-0193 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-26905
# The requested sequence is ep2d_diff_tra_DYNDIST2
# The ijk requested is [65 69 11],OK since shapes of the image is (57, 128, 120)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3438 para el paciente ProstateX-0193 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 8 = 8
# The sequence selected is 8-ep2ddifftraDYNDISTCALCBVAL-27743
# The requested sequence is ep2d_diff_tra_DYNDISTCALC_BVAL0
# The ijk requested is [65 69 11],OK since shapes of the image is (19, 128, 120)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3439 para el paciente ProstateX-0193 serie: ep2d_diff_tra_DYNDISTCALC_BVAL
# ===============================================================
# The condition is true 2 = 2
# The sequence selected is 2-t2loc sag-46184
# The requested sequence is t2_loc_sag0
# The ijk requested is [145 131 0],OK since shapes of the image is (3, 256, 256)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3440 para el paciente ProstateX-0193 serie: t2_loc sag
# ===============================================================
# The condition is true 1 = 1
# The sequence selected is 1-t2localizer-68630
# The requested sequence is t2_localizer0
# The ijk requested is [157 122 0],OK since shapes of the image is (13, 256, 256)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3441 para el paciente ProstateX-0193 serie: t2_localizer
# ===============================================================
# The condition is true 5 = 5
# The sequence selected is 5-t2tsecor-45586
# The requested sequence is t2_tse_cor0
# The ijk requested is [186 142 11],OK since shapes of the image is (15, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3442 para el paciente ProstateX-0193 serie: t2_tse_cor
# ===============================================================
# The condition is true 3 = 3
# The sequence selected is 3-t2tsesag-46320
# The requested sequence is t2_tse_sag0
# The ijk requested is [185 148 6],OK since shapes of the image is (19, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3443 para el paciente ProstateX-0193 serie: t2_tse_sag
# ===============================================================
# The condition is true 4 = 4
# The sequence selected is 4-t2tsetra-90291
# The requested sequence is t2_tse_tra0
# The ijk requested is [209 209 11],OK since shapes of the image is (19, 384, 384)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3444 para el paciente ProstateX-0193 serie: t2_tse_tra
# ===============================================================
# The condition is true 9 = 9
# The sequence selected is 9-tfl3d PD reftra1.5x1.5t3-19551
# The requested sequence is tfl_3d_PD_ref_tra_1_5x1_5_t30
# The ijk requested is [70 70 8],OK since shapes of the image is (16, 128, 128)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3445 para el paciente ProstateX-0193 serie: tfl_3d PD ref_tra_1.5x1.5_t3
# ===============================================================
# The condition is true 7 = 7
# The sequence selected is 7-ep2ddifftraDYNDISTADC-04182
# The requested sequence is ep2d_diff_tra_DYNDIST_ADC0
# The ijk requested is [53 67 14],OK since shapes of the image is (19, 128, 120)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3446 para el paciente ProstateX-0193 serie: ep2d_diff_tra_DYNDIST_ADC
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-26905
# The requested sequence is ep2d_diff_tra_DYNDIST0
# The ijk requested is [53 67 14],OK since shapes of the image is (57, 128, 120)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3447 para el paciente ProstateX-0193 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-26905
# The requested sequence is ep2d_diff_tra_DYNDIST1
# The ijk requested is [53 67 14],OK since shapes of the image is (57, 128, 120)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3448 para el paciente ProstateX-0193 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-26905
# The requested sequence is ep2d_diff_tra_DYNDIST2
# The ijk requested is [53 67 14],OK since shapes of the image is (57, 128, 120)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3449 para el paciente ProstateX-0193 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 8 = 8
# The sequence selected is 8-ep2ddifftraDYNDISTCALCBVAL-27743
# The requested sequence is ep2d_diff_tra_DYNDISTCALC_BVAL0
# The ijk requested is [53 67 14],OK since shapes of the image is (19, 128, 120)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3450 para el paciente ProstateX-0193 serie: ep2d_diff_tra_DYNDISTCALC_BVAL
# ===============================================================
# The condition is true 2 = 2
# The sequence selected is 2-t2loc sag-46184
# The requested sequence is t2_loc_sag0
# The ijk requested is [143 121 3], there was an error since the shapes of the image is (3, 256, 256)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3451 para el paciente ProstateX-0193 serie: t2_loc sag
# ===============================================================
# The condition is true 1 = 1
# The sequence selected is 1-t2localizer-68630
# The requested sequence is t2_localizer0
# The ijk requested is [156 114 0],OK since shapes of the image is (13, 256, 256)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3452 para el paciente ProstateX-0193 serie: t2_localizer
# ===============================================================
# The condition is true 5 = 5
# The sequence selected is 5-t2tsecor-45586
# The requested sequence is t2_tse_cor0
# The ijk requested is [148 123 10],OK since shapes of the image is (15, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3453 para el paciente ProstateX-0193 serie: t2_tse_cor
# ===============================================================
# The condition is true 3 = 3
# The sequence selected is 3-t2tsesag-46320
# The requested sequence is t2_tse_sag0
# The ijk requested is [182 127 12],OK since shapes of the image is (19, 320, 320)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3454 para el paciente ProstateX-0193 serie: t2_tse_sag
# ===============================================================
# The condition is true 4 = 4
# The sequence selected is 4-t2tsetra-90291
# The requested sequence is t2_tse_tra0
# The ijk requested is [164 201 14],OK since shapes of the image is (19, 384, 384)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3455 para el paciente ProstateX-0193 serie: t2_tse_tra
# ===============================================================
# The condition is true 9 = 9
# The sequence selected is 9-tfl3d PD reftra1.5x1.5t3-19551
# The requested sequence is tfl_3d_PD_ref_tra_1_5x1_5_t30
# The ijk requested is [55 67 12],OK since shapes of the image is (16, 128, 128)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3456 para el paciente ProstateX-0193 serie: tfl_3d PD ref_tra_1.5x1.5_t3
# ===============================================================
# The condition is true 7 = 7
# The sequence selected is 7-ep2ddifftraDYNDISTADC-04182
# The requested sequence is ep2d_diff_tra_DYNDIST_ADC0
# The ijk requested is [58 69 7],OK since shapes of the image is (19, 128, 120)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3457 para el paciente ProstateX-0193 serie: ep2d_diff_tra_DYNDIST_ADC
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-26905
# The requested sequence is ep2d_diff_tra_DYNDIST0
# The ijk requested is [58 69 7],OK since shapes of the image is (57, 128, 120)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3458 para el paciente ProstateX-0193 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-26905
# The requested sequence is ep2d_diff_tra_DYNDIST1
# The ijk requested is [58 69 7],OK since shapes of the image is (57, 128, 120)
# Se ha cargado la imagen MRI3D y MRI3DPATCH #3459 para el paciente ProstateX-0193 serie: ep2d_diff_tra_DYNDIST
# ===============================================================
# The condition is true 6 = 6
# The sequence selected is 6-ep2ddifftraDYNDIST-26905
# The requested sequence is ep2d_diff_tra_DYNDIST2

# %%
#find substrings
def return_MRI_serie_of_interest(serie_of_interest):
    for i in range (len( training_MRI_imgs_dataframe )):
        training_MRI_imgs_dataframe.at[i,"InterestSequence"] = False
        if (training_MRI_imgs_dataframe.DCMSerDescr.iloc[i].find(serie_of_interest) != -1):
            training_MRI_imgs_dataframe.at[i,"InterestSequence"] = True

    dataframe = training_MRI_imgs_dataframe[ training_MRI_imgs_dataframe.InterestSequence == True ]
    return dataframe

# %%
#DWI-ADC
serie_of_interest = "adc"
dyndist_adc_dataframe = return_MRI_serie_of_interest(serie_of_interest)
dyndist_adc_dataframe.reset_index(drop=True)
dyndist_adc_dataframe.index = pd.RangeIndex(len(dyndist_adc_dataframe))

#t2_tse_sag
serie_of_interest = "t2_tse_sag"
t2_tse_sag_dataframe = return_MRI_serie_of_interest(serie_of_interest)
t2_tse_sag_dataframe.reset_index(drop=True)
t2_tse_sag_dataframe.index = pd.RangeIndex(len(t2_tse_sag_dataframe))

#t2_tse_tra
serie_of_interest = "t2_tse_tra"
t2_tse_tra_dataframe = return_MRI_serie_of_interest(serie_of_interest)
t2_tse_tra_dataframe.reset_index(drop=True)
t2_tse_tra_dataframe.index = pd.RangeIndex(len(t2_tse_tra_dataframe))

# %%
def setup_MRI_series_descriptions():
    for i in range (len(training_MRI_imgs_dataframe)):
        DCM_description = str.lower( training_MRI_imgs_dataframe.DCMSerDescr.iloc[i] )
        DCM_description = DCM_description.replace(" ","_")
        DCM_description = DCM_description.replace("-","_")
        training_MRI_imgs_dataframe.at[i,"DCMSerDescr"] = DCM_description
    print(training_MRI_imgs_dataframe.DCMSerDescr.unique())

setup_MRI_series_descriptions()

# %%
def get_dataframe_given_zone(zone, dataFrame):
    dataFrame = dataFrame[dataFrame.zone == zone]
    return dataFrame

# %%
def get_data_labels (dataFrame):
    indexes = dataFrame.index
    data = dataFrame.MRIPatch3D
    labels = dataFrame.ClinSig
    z,y,x = [3,40,40]
    all_data = np.empty(shape= (len(data), z*y*x ) )
    all_labels = np.zeros(shape= (len(data) ) )
    i = 0
    for index in indexes:
        all_data[i,:] = data[index].reshape((1,x*y*z))
        label = labels [index]
        all_labels[i] = label
        i = i + 1
    return all_data, all_labels

# %%
def apply_Kfold_cross_validation(data, labels, classifier, kfolds):
    from sklearn.model_selection import cross_val_score
    #data, labels = get_data_labels(dataframe)

    scores = cross_val_score(classifier, data, labels, cv= kfolds)
    print(scores)
    print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
    return scores, scores.mean()*100, scores.std()*100

# %%
def plot_ROC_curve(classifier, data_test, labels_test):
    from sklearn import metrics
    probs = classifier.predict_proba(data_test)
    preds = probs[:,1]
    fpr, tpr, threshold = metrics.roc_curve(labels_test, preds)
    roc_auc = metrics.auc(fpr, tpr)
    import matplotlib.pyplot as plt
    plt.figure(figsize=(10,10))
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %% [markdown]
# ## LeNet Model
#
# In the following cells we are going to introduce the LeNet Deep learning arquitecture, we are going to make some experiments in order to study the behavior of this model with our data.

# %%
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import InputLayer, Input
from tensorflow.python.keras.layers import Reshape, MaxPooling2D
from tensorflow.python.keras.layers import Conv2D, Dense, Flatten, Dropout

# %%
from sklearn.model_selection import train_test_split
data,labels = get_data_labels (training_ktrans_imgs_dataframe)
data_train, data_test, labels_train, labels_test = train_test_split(
    data,labels, test_size = 0.4, shuffle = False)

from tensorflow.python.keras.optimizers import SGD
optimizer = SGD(lr=1e-3)

# %%
img_shape_full = (3,window,window)

model = keras.Sequential()
model.add(InputLayer(input_shape=(img_size_flat,)))
model.add(Reshape(img_shape_full))
model.add(layers.Conv2D(filters=6, kernel_size=(3, 3), activation='relu', name = "1st Conv2D" ))
model.add(layers.AveragePooling2D( pool_size=2, strides=2, name = "2nd subsampling" ))
model.add(layers.Conv2D(filters=16, kernel_size=(3, 3), activation='relu'), name = "3rd Conv2D")
model.add(layers.AveragePooling2D( pool_size=2, strides=2, name = "4th subsampling" ))
model.add(layers.Flatten())
model.add(layers.Dense(units=120, activation='relu', name = "5th FC layer"))
model.add(layers.Dense(units=84, activation='relu', name = "6th FC layer"))
model.add(layers.Dense(units=10, activation = 'softmax'))
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
history= model.fit(x=data.x_train,
          y=data.y_train,
          epochs=10, batch_size=32)

# %% [markdown]
# ## Pre-Processing modalities
#
# In the following cells We would introduce some code in order to avoid duplicated annotations.

# %%
print("This is the $K^{trans} image serie$")
list_of_k_findings = []
dataframe = training_ktrans_imgs_dataframe
print("There is a total of {} rows".format(len(dataframe)))
i = 0
for patient_id in dataframe.ProxID.unique():
    for fid in dataframe[dataframe.ProxID == patient_id].fid.unique():
        list_of_k_findings.append("{} - {}".format(patient_id,fid))
        i = i + 1
print("There are {} findings".format(i))
# Out:
# There is a total of 339 rows
# There are 325 findings

# %%
print("This is the ADC-DWI image series")
list_of_adc_findings = []
dataframe = dyndist_adc_dataframe
print("There is a total of {} rows".format(len(dataframe)))
i = 0
for patient_id in dataframe.ProxID.unique():
    for fid in dataframe[dataframe.ProxID == patient_id].fid.unique():
        list_of_adc_findings.append("{} - {}".format(patient_id,fid))
        i = i + 1
print("There are {} findings".format(i))
# Out:
# There is a total of 345 rows
# There are 323 findings

# %%
print("This is the T2 Weighted image transversal plane")
list_of_t2_tra_findings = []
dataframe = t2_tse_tra_dataframe
print("There is a total of {} rows".format(len(dataframe)))
i = 0
for patient_id in dataframe.ProxID.unique():
    for fid in dataframe[dataframe.ProxID == patient_id].fid.unique():
        list_of_t2_tra_findings.append("{} - {}".format(patient_id,fid))
        i = i + 1
print("There are {} findings".format(i))
# Out:
# There is a total of 415 rows
# There are 325 findings

# %%
print("This is the T2 weighted image sagittal plane")
list_of_t2_sag_findings = []
dataframe = t2_tse_sag_dataframe
print("There is a total of {} rows".format(len(dataframe)))
i = 0
for patient_id in dataframe.ProxID.unique():
    for fid in dataframe[dataframe.ProxID == patient_id].fid.unique():
        list_of_t2_sag_findings.append("{} - {}".format(patient_id,fid))
        i = i + 1
print("There are {} findings".format(i))
# Out:
# There is a total of 363 rows
# There are 324 findings

# %%
list_of_elements_tobe_deleted = []
for finding in list_of_k_findings:
    if (finding not in  list_of_adc_findings):
        if (finding not in list_of_elements_tobe_deleted):
            list_of_elements_tobe_deleted.append(finding)
            
for finding in list_of_k_findings:
    if (finding not in  list_of_t2_sag_findings):
        if (finding not in list_of_elements_tobe_deleted):
            list_of_elements_tobe_deleted.append(finding)
            
for finding in list_of_k_findings:
    if (finding not in  list_of_t2_tra_findings):
        if (finding not in list_of_elements_tobe_deleted):
            list_of_elements_tobe_deleted.append(finding)

# %%
list_of_elements_tobe_deleted
# Out:
# ['ProstateX-0080 - 1',
#  'ProstateX-0140 - 2',
#  'ProstateX-0013 - 1',
#  'ProstateX-0130 - 1',
#  'ProstateX-0172 - 1']

# %%
dataframe = training_ktrans_imgs_dataframe
index_to_delete = []
for finding in list_of_elements_tobe_deleted:
    ProxID,fid = finding.split(" - ")
    dataframe2 = dataframe[(dataframe.ProxID == ProxID) & (dataframe.fid == int(fid)) ]
    if (len(dataframe2) != 0):
        index = dataframe2.index[0]
        index_to_delete.append(index)
        print(index)
        dataframe.at[index,"State"] = True
# Out:
# 119
# 223
# 21
# 200
# 282

# %%
training_ktrans_imgs_dataframe = training_ktrans_imgs_dataframe.drop(index_to_delete)
training_ktrans_imgs_dataframe.reset_index(drop=True)
training_ktrans_imgs_dataframe.index = pd.RangeIndex(len(training_ktrans_imgs_dataframe))

# %%
training_ktrans_imgs_dataframe[training_ktrans_imgs_dataframe.State == True][["ProxID","fid","State"]]
# Out:
# Empty DataFrame
# Columns: [ProxID, fid, State]
# Index: []

# %%
dataframe = dyndist_adc_dataframe
index_to_delete = []
for finding in list_of_elements_tobe_deleted:
    ProxID,fid = finding.split(" - ")
    dataframe2 = dataframe[(dataframe.ProxID == ProxID) & (dataframe.fid == int(fid)) ]
    if (len(dataframe2) != 0):
        index = dataframe2.index[0]
        print(index)
        index_to_delete.append(index)
        dataframe.at[index,"State"] = True
# Out:
# 21
# 201
# 282

# %%
dyndist_adc_dataframe = dyndist_adc_dataframe.drop(index_to_delete)
dyndist_adc_dataframe.reset_index(drop=True)
dyndist_adc_dataframe.index = pd.RangeIndex(len(dyndist_adc_dataframe))
dyndist_adc_dataframe[dyndist_adc_dataframe.State == True][["ProxID","fid","State"]]
# Out:
# Empty DataFrame
# Columns: [ProxID, fid, State]
# Index: []

# %%
dataframe = t2_tse_sag_dataframe
index_to_delete = []
for finding in list_of_elements_tobe_deleted:
    ProxID,fid = finding.split(" - ")
    dataframe2 = dataframe[(dataframe.ProxID == ProxID) & (dataframe.fid == int(fid)) ]
    if (len(dataframe2) != 0):
        index = dataframe2.index[0]
        index_to_delete.append(index)
        print(index)
        dataframe.at[index,"State"] = True
# Out:
# 128
# 239

# %%
t2_tse_sag_dataframe = t2_tse_sag_dataframe.drop(index_to_delete)
t2_tse_sag_dataframe.reset_index(drop=True)
t2_tse_sag_dataframe.index = pd.RangeIndex(len(t2_tse_sag_dataframe))
t2_tse_sag_dataframe[t2_tse_sag_dataframe.State == True][["ProxID","fid","State"]]
# Out:
# Empty DataFrame
# Columns: [ProxID, fid, State]
# Index: []

# %%
dataframe = t2_tse_tra_dataframe
index_to_delete = []
for finding in list_of_elements_tobe_deleted:
    ProxID,fid = finding.split(" - ")
    dataframe2 = dataframe[(dataframe.ProxID == ProxID) & (dataframe.fid == int(fid)) ]
    if (len(dataframe2) != 0):
        index = dataframe2.index[0]
        print(index)
        index_to_delete.append(index)
        dataframe.at[index,"State"] = True
# Out:
# 136
# 263
# 24
# 239
# 343

# %%
t2_tse_tra_dataframe = t2_tse_tra_dataframe.drop(index_to_delete)
t2_tse_tra_dataframe.reset_index(drop=True)
t2_tse_tra_dataframe.index = pd.RangeIndex(len(t2_tse_tra_dataframe))
t2_tse_tra_dataframe[t2_tse_tra_dataframe.State == True][["ProxID","fid","State"]]
# Out:
# Empty DataFrame
# Columns: [ProxID, fid, State]
# Index: []

# %%
print(len(training_ktrans_imgs_dataframe))
print(len(t2_tse_sag_dataframe))
print(len(t2_tse_tra_dataframe))
print(len(dyndist_adc_dataframe))
# Out:
# 334
# 361
# 410
# 342

# %%
dyndist_adc_dataframe.to_pickle("pickle/dyndist_adc_dataframe.pickle")
training_ktrans_imgs_dataframe.to_pickle("pickle/ktrans_dataframe.pickle")
t2_tse_sag_dataframe.to_pickle("pickle/t2_tse_sag_dataframe.pickle")

# %%
t2_tse_tra_dataframe.to_pickle("pickle/t2_tse_tra_dataframe.pickle")
